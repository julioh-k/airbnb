# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None) # to see all the columns on my dataframe
listing= pd.read_csv('listing.csv',low_memory=False)
calendar = pd.read_csv('calendar.csv')
review =pd.read_csv('reviews 2.csv')

# %%
listing.drop(['scrape_id','host_thumbnail_url','host_picture_url','host_listings_count',
              'host_verifications','host_identity_verified','neighbourhood','neighbourhood_cleansed',
             'neighbourhood_group_cleansed','bathrooms','availability_30','availability_60','availability_90','availability_365',
             'calendar_last_scraped','number_of_reviews_ltm','number_of_reviews_l30d','license','instant_bookable',
             'calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms',
             'calculated_host_listings_count_shared_rooms','host_response_time','host_response_rate','host_acceptance_rate','minimum_minimum_nights',
             'maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm',
             'calendar_updated','first_review','last_review'],axis=1,inplace=True)

calendar.drop('adjusted_price',axis=1,inplace=True)

# %%
print('listings shape: ',listing.shape)
print('calendar shape: ', calendar.shape)
print('review shape: ', review.shape)
# Out:
# listings shape:  (37713, 39)
# calendar shape:  (13758434, 6)
# review shape:  (876200, 6)

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37713 entries, 0 to 37712
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           37713 non-null  int64
#  1   listing_url                  37713 non-null  object
#  2   last_scraped                 37713 non-null  object
#  3   name                         37700 non-null  object
#  4   description                  36509 non-null  object
#  5   neighborhood_overview        22506 non-null  object
#  6   picture_url                  37713 non-null  object
#  7   host_id                      37713 non-null  int64
#  8   host_url                     37713 non-null  object
#  9   host_name                    37682 non-null  object
#  10  host_since                   37682 non-null  object
#  11  host_location                37579 non-null  object
#  12  host_about                   21942 non-null  object
#  13  host_is_superhost            37682 non-null  object
#  14  host_neighbourhood           30342 non-null  object
#  15  host_total_listings_count    37682 non-null  float64
#  16  host_has_profile_pic         37682 non-null  object
#  17  latitude                     37713 non-null  float64
#  18  longitude                    37713 non-null  float64
#  19  property_type                37713 non-null  object
#  20  room_type                    37713 non-null  object
#  21  accommodates                 37713 non-null  int64
#  22  bathrooms_text               37602 non-null  object
#  23  bedrooms                     33752 non-null  float64
#  24  beds                         35464 non-null  float64
#  25  amenities                    37713 non-null  object
#  26  price                        37713 non-null  object
#  27  minimum_nights               37713 non-null  int64
#  28  maximum_nights               37713 non-null  int64
#  29  has_availability             37713 non-null  object
#  30  number_of_reviews            37713 non-null  int64
#  31  review_scores_rating         28500 non-null  float64
#  32  review_scores_accuracy       27879 non-null  float64
#  33  review_scores_cleanliness    27890 non-null  float64
#  34  review_scores_checkin        27872 non-null  float64
#  35  review_scores_communication  27883 non-null  float64
#  36  review_scores_location       27868 non-null  float64
#  37  review_scores_value          27868 non-null  float64
#  38  reviews_per_month            28501 non-null  float64
# dtypes: float64(13), int64(6), object(20)
# memory usage: 11.2+ MB

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13758434 entries, 0 to 13758433
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   minimum_nights  float64
#  5   maximum_nights  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 629.8+ MB

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 876200 entries, 0 to 876199
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     876200 non-null  int64
#  1   id             876200 non-null  int64
#  2   date           876200 non-null  object
#  3   reviewer_id    876200 non-null  int64
#  4   reviewer_name  876194 non-null  object
#  5   comments       875334 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 40.1+ MB

# %%
listing.isnull().sum()
# Out:
# id                                0
# listing_url                       0
# last_scraped                      0
# name                              0
# description                       0
# neighborhood_overview             0
# picture_url                       0
# host_id                           0
# host_url                          0
# host_name                         0
# host_since                        0
# host_location                     0
# host_about                        0
# host_is_superhost                 0
# host_neighbourhood                0
# host_total_listings_count         0
# host_has_profile_pic              0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms_text                    0
# bedrooms                          0
# beds                              0
# amenities                         0
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# has_availability                  0
# number_of_reviews                 0
# review_scores_rating           9213
# review_scores_accuracy         9834
# review_scores_cleanliness      9823
# review_scores_checkin          9841
# review_scores_communication    9830
# review_scores_location         9845
# review_scores_value            9845
# reviews_per_month              9212
# dtype: int64

# %%
calendar
# Out:
#           listing_id        date available    price  minimum_nights  \
# 0              16821  2021-11-03         t  $124.00             1.0
# 1              16595  2021-11-03         f  $450.00             1.0
# 2              16595  2021-11-04         f  $450.00             1.0
# 3              16595  2021-11-05         f  $490.00             1.0
# 4              16595  2021-11-06         t  $490.00             1.0
# ...              ...         ...       ...      ...             ...
# 13758429    53077932  2022-10-29         t  $135.00             5.0
# 13758430    53077932  2022-10-30         t  $135.00             5.0
# 13758431    53077932  2022-10-31         t  $135.00             5.0
# 13758432    53077932  2022-11-01         t  $135.00             5.0
# 13758433    53077932  2022-11-02         t  $135.00             5.0
#
#           maximum_nights
# 0                   30.0
# 1                 1125.0
# 2                 1125.0
# 3                 1125.0
# 4                 1125.0
# ...                  ...
# 13758429          1125.0
# 13758430          1125.0
# 13758431          1125.0
# 13758432          1125.0
# 13758433          1125.0
#
# [13758434 rows x 6 columns]

# %%
calendar.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
review
# Out:
#         listing_id                  id        date  reviewer_id reviewer_name  \
# 0             2595               17857  2009-11-21        50679          Jean
# 1             2595               19176  2009-12-05        53267          Cate
# 2             2595               19760  2009-12-10        38960         Anita
# 3             2595               34320  2010-04-09        71130       Kai-Uwe
# 4             2595               46312  2010-05-25       117113        Alicia
# ...            ...                 ...         ...          ...           ...
# 876195    53032739  484714686054587228  2021-10-30    417858009      Mohammad
# 876196    53032739  486136261420447607  2021-11-01    168447002    Konstantin
# 876197    53038415  485458708697776561  2021-10-31     54989729         Craig
# 876198    53046338  486896061814457176  2021-11-02    263525182        Gersom
# 876199    53080602  486192987669601092  2021-11-01    117840663       Makayla
#
#                                                  comments
# 0       Notre séjour de trois nuits.\r<br/>Nous avons ...
# 1                                       Great experience.
# 2       I've stayed with my friend at the Midtown Cast...
# 3       We've been staying here for about 9 nights, en...
# 4       We had a wonderful stay at Jennifer's charming...
# ...                                                   ...
# 876195  Vanessa is a professional at work. Gave very a...
# 876196                 It’s good place:) very friendly :)
# 876197  Hi All,<br/><br/>This place was exactly as exp...
# 876198  Great place and great value! Would definitely ...
# 876199  The place was spotless better than the picture...
#
# [876200 rows x 6 columns]

# %%
review.isnull().sum()
# Out:
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# comments         0
# dtype: int64

# %% [raw]
# listing['name'].fillna(str(listing['id']), inplace=True)
# listing['description'].fillna('None', inplace=True)
# listing['neighborhood_overview'].fillna('None', inplace=True)
# listing['host_name'].fillna(str(listing['id']), inplace=True)
# listing['host_since'].fillna(listing['host_since'].mode()[0], inplace=True)
# listing['host_location'].fillna('New York, New York, United States', inplace=True)
# listing['host_about'].fillna('None', inplace=True)
# listing['host_is_superhost'].fillna('f', inplace=True)
# listing['host_neighbourhood'].fillna('None', inplace=True)
# listing['host_total_listings_count'].fillna('0', inplace=True)
# listing['host_has_profile_pic'].fillna('f', inplace=True)
# listing['bathrooms_text'].fillna('1 bath', inplace=True)
# listing['bedrooms'].fillna('1.0', inplace=True)
# listing['beds'].fillna(listing['beds'].mode()[0], inplace=True)

# %%
calendar.dropna(subset=['price'],inplace=True)
calendar.dropna(subset=['minimum_nights'],inplace=True)

# %%
review['reviewer_name'].fillna('None', inplace=True)
review['comments'].fillna('None', inplace=True)

# %%
New York, New York, United States

# %%
listing[listing['neighborhood_overview'].isnull()]
# Out:
#              id                            listing_url last_scraped  \
# 2          5121      https://www.airbnb.com/rooms/5121   2021-11-03
# 3          5136      https://www.airbnb.com/rooms/5136   2021-11-03
# 7          6848      https://www.airbnb.com/rooms/6848   2021-11-03
# 12         7750      https://www.airbnb.com/rooms/7750   2021-11-03
# 14         8490      https://www.airbnb.com/rooms/8490   2021-11-03
# ...         ...                                    ...          ...
# 37708  53123149  https://www.airbnb.com/rooms/53123149   2021-11-03
# 37709  53123691  https://www.airbnb.com/rooms/53123691   2021-11-03
# 37710  53123840  https://www.airbnb.com/rooms/53123840   2021-11-03
# 37711  53126354  https://www.airbnb.com/rooms/53126354   2021-11-03
# 37712  53127631  https://www.airbnb.com/rooms/53127631   2021-11-03
#
#                                                    name  \
# 2                                       BlissArtsSpace!
# 3              Spacious Brooklyn Duplex, Patio + Garden
# 7                      Only 2 stops to Manhattan studio
# 12            2 Furnished bedrooms next to Central Park
# 14     Maison des Sirenes1,bohemian, luminous apartment
# ...                                                 ...
# 37708       Lovely Room in Bedford-Stuyvesant Apartment
# 37709         Unfurnished Room in West Harlem Apartment
# 37710   MASSIVE 8BR/8BTH Brooklyn Townhouse w/ Backyard
# 37711         Unfurnished Room in West Harlem Apartment
# 37712              Bright Room in West Harlem Apartment
#
#                                              description  \
# 2      <b>The space</b><br />HELLO EVERYONE AND THANK...
# 3      We welcome you to stay in our lovely 2 br dupl...
# 7      Comfortable studio apartment with super comfor...
# 12     Great location just steps to Central Park.<br ...
# 14     <b>The space</b><br />I am the lucky owner of ...
# ...                                                  ...
# 37708  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...
# 37709  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...
# 37710  Newly renovated townhouse in Bushwick, includi...
# 37711  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...
# 37712  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...
#
#       neighborhood_overview  \
# 2                       NaN
# 3                       NaN
# 7                       NaN
# 12                      NaN
# 14                      NaN
# ...                     ...
# 37708                   NaN
# 37709                   NaN
# 37710                   NaN
# 37711                   NaN
# 37712                   NaN
#
#                                              picture_url    host_id  \
# 2      https://a0.muscache.com/pictures/2090980c-b68e...       7356
# 3      https://a0.muscache.com/pictures/miso/Hosting-...       7378
# 7      https://a0.muscache.com/pictures/e4f031a7-f146...      15991
# 12     https://a0.muscache.com/pictures/30595787/61df...      17985
# 14     https://a0.muscache.com/pictures/1c51369e-a251...      25183
# ...                                                  ...        ...
# 37708  https://a0.muscache.com/pictures/miso/Hosting-...  305240193
# 37709  https://a0.muscache.com/pictures/d977726e-fa65...  305240193
# 37710  https://a0.muscache.com/pictures/a4205ba6-17ab...   13603829
# 37711  https://a0.muscache.com/pictures/bd449765-d34a...  305240193
# 37712  https://a0.muscache.com/pictures/0ccd7178-5c3f...  305240193
#
#                                           host_url      host_name  host_since  \
# 2           https://www.airbnb.com/users/show/7356          Garon  2009-02-03
# 3           https://www.airbnb.com/users/show/7378        Rebecca  2009-02-03
# 7          https://www.airbnb.com/users/show/15991  Allen & Irina  2009-05-06
# 12         https://www.airbnb.com/users/show/17985           Sing  2009-05-20
# 14         https://www.airbnb.com/users/show/25183       Nathalie  2009-07-10
# ...                                            ...            ...         ...
# 37708  https://www.airbnb.com/users/show/305240193           June  2019-10-29
# 37709  https://www.airbnb.com/users/show/305240193           June  2019-10-29
# 37710   https://www.airbnb.com/users/show/13603829            Kay  2014-03-27
# 37711  https://www.airbnb.com/users/show/305240193           June  2019-10-29
# 37712  https://www.airbnb.com/users/show/305240193           June  2019-10-29
#
#                            host_location  \
# 2      New York, New York, United States
# 3      Brooklyn, New York, United States
# 7      New York, New York, United States
# 12     Brooklyn, New York, United States
# 14     New York, New York, United States
# ...                                  ...
# 37708  New York, New York, United States
# 37709  New York, New York, United States
# 37710  Brooklyn, New York, United States
# 37711  New York, New York, United States
# 37712  New York, New York, United States
#
#                                               host_about  host_response_time  \
# 2       I am an artist(painter, filmmaker) and curato...  within a few hours
# 3      Rebecca is an artist/designer, and Henoch is i...        within a day
# 7      We love to travel. When we travel we like to s...      within an hour
# 12       Textile Designer, Art curator in New York City.        within a day
# 14      I am French and have been living in Ny for 10...      within an hour
# ...                                                  ...                 ...
# 37708  If you're searching for a place of your own or...  within a few hours
# 37709  If you're searching for a place of your own or...  within a few hours
# 37710                    Traveler, Entrepreneur, Artist       within an hour
# 37711  If you're searching for a place of your own or...  within a few hours
# 37712  If you're searching for a place of your own or...  within a few hours
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 2                   100%                 100%                 f
# 3                   100%                  25%                 f
# 7                   100%                 100%                 f
# 12                   83%                  29%                 f
# 14                  100%                  98%                 t
# ...                  ...                  ...               ...
# 37708                97%                  18%                 f
# 37709                97%                  18%                 f
# 37710                90%                  83%                 f
# 37711                97%                  18%                 f
# 37712                97%                  18%                 f
#
#        host_neighbourhood  host_total_listings_count host_has_profile_pic  \
# 2      Bedford-Stuyvesant                        1.0                    t
# 3       Greenwood Heights                        1.0                    t
# 7            Williamsburg                        1.0                    t
# 12            East Harlem                        2.0                    t
# 14     Bedford-Stuyvesant                        2.0                    t
# ...                   ...                        ...                  ...
# 37708       Crown Heights                      219.0                    t
# 37709       Crown Heights                      219.0                    t
# 37710          Kensington                       11.0                    t
# 37711       Crown Heights                      219.0                    t
# 37712       Crown Heights                      219.0                    t
#
#         latitude  longitude                property_type        room_type  \
# 2      40.685350 -73.955120  Private room in rental unit     Private room
# 3      40.662650 -73.994540           Entire rental unit  Entire home/apt
# 7      40.709350 -73.953420           Entire rental unit  Entire home/apt
# 12     40.796070 -73.949490  Private room in rental unit     Private room
# 14     40.684620 -73.938390                  Entire loft  Entire home/apt
# ...          ...        ...                          ...              ...
# 37708  40.682389 -73.955540  Private room in rental unit     Private room
# 37709  40.801062 -73.961581  Private room in rental unit     Private room
# 37710  40.682358 -73.908384             Entire townhouse  Entire home/apt
# 37711  40.800454 -73.963746  Private room in rental unit     Private room
# 37712  40.799822 -73.966022  Private room in rental unit     Private room
#
#        accommodates  bathrooms_text  bedrooms  beds  \
# 2                 2             NaN       1.0   1.0
# 3                 4       1.5 baths       2.0   2.0
# 7                 3          1 bath       NaN   1.0
# 12                1   1 shared bath       2.0   2.0
# 14                5          1 bath       1.0   4.0
# ...             ...             ...       ...   ...
# 37708             1  2 shared baths       1.0   1.0
# 37709             1   1 shared bath       1.0   NaN
# 37710             8       7.5 baths       8.0   8.0
# 37711             1   1 shared bath       1.0   NaN
# 37712             1   1 shared bath       1.0   1.0
#
#                                                amenities  price  \
# 2      ["Long term stays allowed", "Heating", "Wifi",...   6000
# 3      ["BBQ grill", "Dryer", "Carbon monoxide alarm"...  27500
# 7      ["Dedicated workspace", "Hair dryer", "Fire ex...   8900
# 12     ["Elevator", "Wifi", "Long term stays allowed"...   9600
# 14     ["Microwave", "Oven", "Private entrance", "Air...  14000
# ...                                                  ...    ...
# 37708  ["Trash compactor", "Long term stays allowed",...   6500
# 37709  ["Hot water kettle", "Trash compactor", "TV", ...   5800
# 37710  ["Long term stays allowed", "Essentials", "Sha...  91400
# 37711  ["Hot water kettle", "Trash compactor", "TV", ...   6600
# 37712  ["Hot water kettle", "Trash compactor", "Carbo...   6500
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 2                  30             730                    30.0
# 3                   5            1125                     5.0
# 7                  30             730                    30.0
# 12                 30             365                    30.0
# 14                  2            1125                     2.0
# ...               ...             ...                     ...
# 37708              30             180                    30.0
# 37709              30             180                    30.0
# 37710               1            1125                     1.0
# 37711              30             180                    30.0
# 37712              30             180                    30.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 2                        30.0                   730.0                   730.0
# 3                         5.0                  1125.0                  1125.0
# 7                        30.0                  1125.0                  1125.0
# 12                       30.0                   365.0                   365.0
# 14                        2.0                  1125.0                  1125.0
# ...                       ...                     ...                     ...
# 37708                    30.0                   180.0                   180.0
# 37709                    30.0                   180.0                   180.0
# 37710                     1.0                  1125.0                  1125.0
# 37711                    30.0                   180.0                   180.0
# 37712                    30.0                   180.0                   180.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 2                        30.0                   730.0               NaN
# 3                         5.0                  1125.0               NaN
# 7                        30.0                  1125.0               NaN
# 12                       30.0                   365.0               NaN
# 14                        2.0                  1125.0               NaN
# ...                       ...                     ...               ...
# 37708                    30.0                   180.0               NaN
# 37709                    30.0                   180.0               NaN
# 37710                     1.0                  1125.0               NaN
# 37711                    30.0                   180.0               NaN
# 37712                    30.0                   180.0               NaN
#
#       has_availability  number_of_reviews first_review last_review  \
# 2                    t                 50   2014-01-22  2016-06-05
# 3                    t                  2   2014-01-02  2021-08-08
# 7                    t                181   2009-12-04  2021-08-10
# 12                   t                  0          NaN         NaN
# 14                   t                138   2012-03-05  2021-10-17
# ...                ...                ...          ...         ...
# 37708                t                  0          NaN         NaN
# 37709                t                  0          NaN         NaN
# 37710                t                  0          NaN         NaN
# 37711                t                  0          NaN         NaN
# 37712                t                  0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 2                      4.52                    4.22
# 3                      5.00                    5.00
# 7                      4.56                    4.59
# 12                      NaN                     NaN
# 14                     4.76                    4.85
# ...                     ...                     ...
# 37708                   NaN                     NaN
# 37709                   NaN                     NaN
# 37710                   NaN                     NaN
# 37711                   NaN                     NaN
# 37712                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 2                           4.09                   4.91
# 3                           5.00                   5.00
# 7                           4.86                   4.84
# 12                           NaN                    NaN
# 14                          4.74                   4.89
# ...                          ...                    ...
# 37708                        NaN                    NaN
# 37709                        NaN                    NaN
# 37710                        NaN                    NaN
# 37711                        NaN                    NaN
# 37712                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 2                             4.91                    4.47
# 3                             5.00                    4.50
# 7                             4.80                    4.67
# 12                             NaN                     NaN
# 14                            4.87                    4.61
# ...                            ...                     ...
# 37708                          NaN                     NaN
# 37709                          NaN                     NaN
# 37710                          NaN                     NaN
# 37711                          NaN                     NaN
# 37712                          NaN                     NaN
#
#        review_scores_value  reviews_per_month
# 2                     4.52               0.53
# 3                     5.00               0.02
# 7                     4.57               1.25
# 12                     NaN                NaN
# 14                    4.75               1.17
# ...                    ...                ...
# 37708                  NaN                NaN
# 37709                  NaN                NaN
# 37710                  NaN                NaN
# 37711                  NaN                NaN
# 37712                  NaN                NaN
#
# [15207 rows x 51 columns]

# %%
listing[listing['neighborhood_overview']==np.nan]
# Out:
#   File "<ipython-input-157-7c985fc0894b>", line 1
#     listing[listing['neighborhood_overview']=np.nan]
#                                             ^
# SyntaxError: invalid syntax

# %%
listing.head()
# Out:
#      id                        listing_url last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595   2021-11-03
# 1  3831  https://www.airbnb.com/rooms/3831   2021-11-03
# 2  5121  https://www.airbnb.com/rooms/5121   2021-11-03
# 3  5136  https://www.airbnb.com/rooms/5136   2021-11-03
# 4  5178  https://www.airbnb.com/rooms/5178   2021-11-03
#
#                                                 name  \
# 0                              Skylit Midtown Castle
# 1  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2                                    BlissArtsSpace!
# 3           Spacious Brooklyn Duplex, Patio + Garden
# 4                   Large Furnished Room Near B'way
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Enjoy 500 s.f. top floor in 1899 brownstone, w...
# 2  <b>The space</b><br />HELLO EVERYONE AND THANK...
# 3  We welcome you to stay in our lovely 2 br dupl...
# 4  Please don’t expect the luxury here just a bas...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1  Just the right mix of urban center and local n...
# 2                                               5121
# 3                                               5136
# 4    Theater district, many restaurants around here.
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845
# 1  https://a0.muscache.com/pictures/e49999c2-9fd5...     4869
# 2  https://a0.muscache.com/pictures/2090980c-b68e...     7356
# 3  https://a0.muscache.com/pictures/miso/Hosting-...     7378
# 4  https://a0.muscache.com/pictures/12065/f070997...     8967
#
#                                  host_url    host_name  host_since  \
# 0  https://www.airbnb.com/users/show/2845     Jennifer  2008-09-09
# 1  https://www.airbnb.com/users/show/4869  LisaRoxanne  2008-12-07
# 2  https://www.airbnb.com/users/show/7356        Garon  2009-02-03
# 3  https://www.airbnb.com/users/show/7378      Rebecca  2009-02-03
# 4  https://www.airbnb.com/users/show/8967     Shunichi  2009-03-03
#
#                        host_location  \
# 0  New York, New York, United States
# 1  New York, New York, United States
# 2  New York, New York, United States
# 3  Brooklyn, New York, United States
# 4  New York, New York, United States
#
#                                           host_about  host_response_time  \
# 0  A New Yorker since 2000! My passion is creatin...  a few days or more
# 1  Laid-back Native New Yorker (formerly bi-coast...  a few days or more
# 2   I am an artist(painter, filmmaker) and curato...  within a few hours
# 3  Rebecca is an artist/designer, and Henoch is i...        within a day
# 4  I used to work for a financial industry but no...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                35%                  18%                 f
# 1                21%                  76%                 f
# 2               100%                 100%                 f
# 3               100%                  25%                 f
# 4               100%                 100%                 f
#
#    host_neighbourhood  host_total_listings_count host_has_profile_pic  \
# 0             Midtown                        8.0                    t
# 1        Clinton Hill                        1.0                    t
# 2  Bedford-Stuyvesant                        1.0                    t
# 3   Greenwood Heights                        1.0                    t
# 4      Hell's Kitchen                        1.0                    t
#
#    latitude  longitude                property_type        room_type  \
# 0  40.75356  -73.98559           Entire rental unit  Entire home/apt
# 1  40.68494  -73.95765           Entire guest suite  Entire home/apt
# 2  40.68535  -73.95512  Private room in rental unit     Private room
# 3  40.66265  -73.99454           Entire rental unit  Entire home/apt
# 4  40.76457  -73.98317  Private room in rental unit     Private room
#
#    accommodates bathrooms_text  bedrooms  beds  \
# 0             1         1 bath       NaN   1.0
# 1             3         1 bath       1.0   3.0
# 2             2            NaN       1.0   1.0
# 3             4      1.5 baths       2.0   2.0
# 4             2         1 bath       1.0   1.0
#
#                                            amenities  price  minimum_nights  \
# 0  ["Bathtub", "Dedicated workspace", "Hair dryer...  15000              30
# 1  ["Microwave", "Oven", "Pack \u2019n play/Trave...   7300               1
# 2  ["Long term stays allowed", "Heating", "Wifi",...   6000              30
# 3  ["BBQ grill", "Dryer", "Carbon monoxide alarm"...  27500               5
# 4  ["Conditioner", "Drying rack for clothing", "H...   6800               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                    30.0                    30.0
# 1             730                     1.0                     1.0
# 2             730                    30.0                    30.0
# 3            1125                     5.0                     5.0
# 4              14                     2.0                     2.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                  1125.0                  1125.0                    30.0
# 1                   730.0                   730.0                     1.0
# 2                   730.0                   730.0                    30.0
# 3                  1125.0                  1125.0                     5.0
# 4                    14.0                    14.0                     2.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  \
# 0                  1125.0               NaN                t
# 1                   730.0               NaN                t
# 2                   730.0               NaN                t
# 3                  1125.0               NaN                t
# 4                    14.0               NaN                t
#
#    number_of_reviews first_review last_review  review_scores_rating  \
# 0                 48   2009-11-21  2019-11-04                  4.70
# 1                408   2015-01-05  2021-06-29                  4.46
# 2                 50   2014-01-22  2016-06-05                  4.52
# 3                  2   2014-01-02  2021-08-08                  5.00
# 4                505   2010-08-18  2021-10-20                  4.21
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.72                       4.62                   4.76
# 1                    4.59                       4.50                   4.79
# 2                    4.22                       4.09                   4.91
# 3                    5.00                       5.00                   5.00
# 4                    4.20                       3.73                   4.66
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.79                    4.86                 4.41
# 1                         4.81                    4.72                 4.65
# 2                         4.91                    4.47                 4.52
# 3                         5.00                    4.50                 5.00
# 4                         4.41                    4.87                 4.35
#
#    reviews_per_month
# 0               0.33
# 1               4.91
# 2               0.53
# 3               0.02
# 4               3.70

# %%
listing['price'] = listing['price'].replace('[\$\,\.]', '', regex=True).astype(int)
calendar['price'] = calendar['price'].replace('[\$\,\.]', '', regex=True).astype(int)

#https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-161bf86327e1> in <module>
#       1 listing['price'] = listing['price'].replace('[\$\,\.]', '', regex=True).astype(int)
# ----> 2 calendar['price'] = calendar['price'].replace('[\$\,\.]', '', regex=True).astype(int)
#       3
#       4 #https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
listing.describe()
# Out:
#                  id       host_id  host_total_listings_count      latitude  \
# count  3.771300e+04  3.771300e+04               37682.000000  37713.000000
# mean   2.883977e+07  1.117833e+08                  44.408471     40.729186
# std    1.710942e+07  1.272200e+08                 294.251560      0.055662
# min    2.595000e+03  2.438000e+03                   0.000000     40.504559
# 25%    1.309845e+07  1.110595e+07                   1.000000     40.689380
# 50%    2.996451e+07  4.886606e+07                   1.000000     40.725160
# 75%    4.547279e+07  1.918493e+08                   3.000000     40.762510
# max    5.312763e+07  4.298401e+08                4067.000000     40.914070
#
#           longitude  accommodates      bedrooms          beds           price  \
# count  37713.000000  37713.000000  33752.000000  35464.000000    37713.000000
# mean     -73.949361      2.784981      1.320811      1.590740    16542.255986
# std        0.050442      1.863980      0.702414      1.077333    29236.618160
# min      -74.249840      0.000000      1.000000      1.000000        0.000000
# 25%      -73.983620      2.000000      1.000000      1.000000     6900.000000
# 50%      -73.955020      2.000000      1.000000      1.000000    11000.000000
# 75%      -73.930950      4.000000      1.000000      2.000000    18000.000000
# max      -73.710870     16.000000     13.000000     24.000000  1000000.000000
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# count    37713.000000    3.771300e+04            37694.000000
# mean        22.130645    5.866011e+04               22.298058
# std         30.809556    1.105915e+07               33.661902
# min          1.000000    1.000000e+00                1.000000
# 25%          3.000000    6.000000e+01                3.000000
# 50%         30.000000    1.125000e+03               30.000000
# 75%         30.000000    1.125000e+03               30.000000
# max       1250.000000    2.147484e+09             1250.000000
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# count            37694.000000            3.769400e+04            3.769400e+04
# mean                28.155542            1.654037e+06            3.534100e+06
# std                 70.500662            5.954322e+07            8.702382e+07
# min                  1.000000            1.000000e+00            1.000000e+00
# 25%                  3.000000            3.000000e+02            3.650000e+02
# 50%                 30.000000            1.125000e+03            1.125000e+03
# 75%                 30.000000            1.125000e+03            1.125000e+03
# max               1250.000000            2.147484e+09            2.147484e+09
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# count            37694.000000            3.769400e+04               0.0
# mean                27.789574            2.255370e+06               NaN
# std                 68.661471            6.506941e+07               NaN
# min                  1.000000            1.000000e+00               NaN
# 25%                  3.000000            3.600000e+02               NaN
# 50%                 30.000000            1.125000e+03               NaN
# 75%                 30.000000            1.125000e+03               NaN
# max               1250.000000            2.147484e+09               NaN
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# count       37713.000000          28500.000000            27879.000000
# mean           23.233368              4.584785                4.746614
# std            50.153962              0.839473                0.491423
# min             0.000000              0.000000                0.000000
# 25%             1.000000              4.570000                4.710000
# 50%             4.000000              4.820000                4.900000
# 75%            20.000000              5.000000                5.000000
# max          1009.000000              5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               27890.000000           27872.000000
# mean                    4.613382               4.816832
# std                     0.572011               0.435073
# min                     0.000000               0.000000
# 25%                     4.500000               4.810000
# 50%                     4.800000               4.960000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 27883.000000            27868.000000
# mean                      4.811570                4.752293
# std                       0.456708                0.412702
# min                       0.000000                0.000000
# 25%                       4.820000                4.670000
# 50%                       4.970000                4.880000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  reviews_per_month
# count         27868.000000       28501.000000
# mean              4.650597           1.640820
# std               0.511760           4.220807
# min               0.000000           0.010000
# 25%               4.560000           0.120000
# 50%               4.780000           0.470000
# 75%               5.000000           1.690000
# max               5.000000         136.000000
